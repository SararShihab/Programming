# %% [markdown]
# # 1.Python Output

# %%
print("Hello World")
# Out:
# Hello World

# %%
print('Hello World')
# Out:
# Hello World

# %%
print(shovo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-2853893128.py in <cell line: 0>()
# ----> 1 print(shovo)
#
# NameError: name 'shovo' is not defined

# %%
print(5)
# Out:
# 5

# %%
print(True)
# Out:
# True

# %%
print("Hello",5,True)
# Out:
# Hello 5 True

# %%
print("Hello",5,True, sep='/')
# Out:
# Hello/5/True

# %%
print("Hello",5,True, sep='-')
# Out:
# Hello-5-True

# %%
print("Sabit",end="")
print("robin")
# Out:
# Sabitrobin

# %% [markdown]
# # 2.Data Types

# %%
#Integer
print(5)
# print(1e308)
print(1e308)
# Out:
# 5
# 1e+308

# %%
# Float / Decimal

print(11.5)
# 1.7e308
print(1.7e309)
# Out:
# 11.5
# inf

# %%
# Boolean

print(True)
print(False)
# Out:
# True
# False

# %%
# String / Text
print("Hello World")
# Out:
# Hello World

# %%
type('c')
# Out:
# str

# %%
# List
print([1,2,3,4,5,"Shovo"])
# Out:
# [1, 2, 3, 4, 5, 'Shovo']

# %%
# Tuple
print((1,2,3,4,5,"Shovo"))
# Out:
# (1, 2, 3, 4, 5, 'Shovo')

# %%
# Sets
print({1,2,3,4,5,"Shovo"})
# Out:
# {1, 2, 3, 4, 5, 'Shovo'}

# %%
# Dictionary
print({"Name":"Shovo","Age":22})
# Out:
# {'Name': 'Shovo', 'Age': 22}

# %%
a = "robin"

# %%
a[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-34-66174252.py in <cell line: 0>()
# ----> 1 a[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
type([1,2,3,4,5,"Shovo"])
# Out:
# list

# %% [markdown]
# # 3. Variable

# %%
# Static Typing Vs Dynamic Typing
# Static Binding vs Dynamic Binding

# %%
# C / C++
# int a = 5
# Dynamic  Typing
a = 5

# %%
print(5)
# Out:
# 5

# %%
# Dynamic Binding
b = 5
b = 6
b
# Out:
# 6

# %%
a,b,c = 1,2,3
a = b = c  = 10

print( a )
# Out:
# 10

# %% [markdown]
# 4. Comments

# %%
# This is Shovo
ab = "Rafi"  # Rafi

# %% [markdown]
# # 5. *Keywords* & Identifier
#
# ```
# # This is formatted as code
# ```

# %%
ab1 = "Rafi_Robin"
# You cant start with number

_ab = "mahir"

_ = "mahir"

# Identifiers can not be keywords

# %% [markdown]
# # 6. User Input

# %%
input("Enter your name")
# Out:
# Enter your nameSafaruzzaman
# 'Safaruzzaman '

# %%
a = input("Enter Your Name")
# Out:
# Enter Your NameSafaruzzaman Shovo

# %%
input()
# Out:
# Safaruzzaman
# 'Safaruzzaman '

# %%
a = int(input())
# Out:
# 5

# %%
type(a)
# Out:
# int
